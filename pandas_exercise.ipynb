# %% [markdown]
# # Pandas Exercises

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ## Exercise 1 — Build a Sales Tracker from Scratch (Series)
#
# You work as a data analyst at a retail chain. Your manager asks you to quickly
# summarise this week's daily revenue from five stores.
#
# ```
# Store A: 84500
# Store B: 91200
# Store C: 67800
# Store D: 105300
# Store E: 78600
# ```
#
# Create a `pd.Series` named `revenue` where the store names are the index labels.
# Then answer the following:
# 1. What is the total revenue across all stores?
# 2. Which store had the highest revenue? (use `idxmax()`)
# 3. Which store had the lowest revenue? (use `idxmin()`)
# 4. What is the average daily revenue per store?

# %%
# 1. Create the Series with store names as index labels


# 2. Total revenue


# 3. Best performing store


# 4. Worst performing store


# 5. Average revenue

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Total revenue    : 427400
# Best store       : Store D
# Worst store      : Store C
# Average revenue  : 85480.0
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 2 — Product Inventory Sheet (DataFrame from dictionary)
#
# A warehouse analyst needs a quick inventory table.
# Create a DataFrame called `inventory` from the data below, then:
#
# 1. Print the shape of the DataFrame.
# 2. Add a new column `TotalValue` = `UnitPrice` * `Quantity`.
# 3. Print the row with the highest `TotalValue` using `idxmax()`.
#
# ```python
# {
#     'Product'   : ['Laptop', 'Keyboard', 'Monitor', 'Mouse', 'Webcam'],
#     'Category'  : ['Electronics', 'Accessories', 'Electronics', 'Accessories', 'Electronics'],
#     'UnitPrice'  : [55000, 1500, 18000, 800, 3200],
#     'Quantity'   : [30, 200, 45, 300, 80]
# }
# ```

# %%
# 1. Create the inventory DataFrame


# 2. Print the shape


# 3. Add TotalValue column


# 4. Print the row with the highest TotalValue

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Shape: (5, 4)
#
# Highest TotalValue row:
# Product      Laptop
# Category     Electronics
# UnitPrice    55000
# Quantity     30
# TotalValue   1650000
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 3 — Customer Records (DataFrame from list of dicts)
#
# A CRM analyst receives customer sign-up data as a list of records (one dict per customer).
# This is the format you often get from a JSON API.
#
# Create a DataFrame called `customers` from the records below:
#
# ```python
# [
#     {"CustomerID": "C001", "Name": "Ananya",  "City": "Mumbai",    "Plan": "Premium", "MonthlySpend": 1200},
#     {"CustomerID": "C002", "Name": "Rohan",   "City": "Delhi",     "Plan": "Basic",   "MonthlySpend": 499},
#     {"CustomerID": "C003", "Name": "Meera",   "City": "Bangalore", "Plan": "Premium", "MonthlySpend": 1200},
#     {"CustomerID": "C004", "Name": "Vikram",  "City": "Chennai",   "Plan": "Standard","MonthlySpend": 799},
#     {"CustomerID": "C005", "Name": "Priya",   "City": "Mumbai",    "Plan": "Basic",   "MonthlySpend": 499},
#     {"CustomerID": "C006", "Name": "Rahul",   "City": "Kolkata",   "Plan": "Standard","MonthlySpend": 799},
# ]
# ```
#
# Then:
# 1. Set `CustomerID` as the index using `.set_index()`.
# 2. Access Meera's full record using `.loc[]`.
# 3. Print how many customers are on each Plan using `value_counts()`.

# %%
# 1. Create the customers DataFrame


# 2. Set CustomerID as the index


# 3. Access Meera's record (CustomerID: C003)


# 4. Count customers per Plan

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Meera's record:
# Name            Meera
# City         Bangalore
# Plan           Premium
# MonthlySpend      1200
#
# Plan counts:
# Basic       2
# Standard    2
# Premium     2
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 4 — Selecting and Filtering Sales Data
#
# You are given a quarterly sales report. Practice selecting and filtering specific rows and columns.
#
# ```python
# sales_data = pd.DataFrame({
#     'SalesRep'  : ['Aisha', 'Ben', 'Clara', 'David', 'Eva', 'Frank'],
#     'Region'    : ['North', 'South', 'North', 'East', 'South', 'East'],
#     'Q1_Sales'  : [82000, 67000, 91000, 54000, 78000, 63000],
#     'Q2_Sales'  : [88000, 71000, 85000, 60000, 92000, 58000],
#     'Target'    : [85000, 70000, 90000, 65000, 80000, 65000]
# })
# ```
#
# Tasks:
# 1. Select only the `SalesRep` and `Q2_Sales` columns.
# 2. Using `.loc[]`, filter rows where `Region` is `'North'`.
# 3. Using `.iloc[]`, select the first 3 rows and first 3 columns.
# 4. Add a column `HitTarget` = `True` if `Q2_Sales` >= `Target`, else `False`. (One line, no loop needed.)

# %%
sales_data = pd.DataFrame({
    'SalesRep' : ['Aisha', 'Ben', 'Clara', 'David', 'Eva', 'Frank'],
    'Region'   : ['North', 'South', 'North', 'East', 'South', 'East'],
    'Q1_Sales' : [82000, 67000, 91000, 54000, 78000, 63000],
    'Q2_Sales' : [88000, 71000, 85000, 60000, 92000, 58000],
    'Target'   : [85000, 70000, 90000, 65000, 80000, 65000]
})

# 1. Select SalesRep and Q2_Sales columns


# 2. Filter rows where Region is 'North'


# 3. First 3 rows, first 3 columns using iloc


# 4. Add HitTarget column

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# SalesRep + Q2_Sales:
#   SalesRep  Q2_Sales
# 0    Aisha     88000
# 1      Ben     71000
# ...
#
# North region reps: Aisha, Clara
#
# HitTarget column: [True, True, False, False, True, False]
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 5 — Load the Employee Dataset
#
# Run the cell below to create the employee dataset used for Exercises 6 to 15.
# This mirrors data you would receive from an HR system export.
#
# After running it, use `.info()` and `.describe()` to understand the shape,
# dtypes, and which columns have missing values.

# %%
# Run this cell as-is — it creates the working dataset

data = {
    'Name'         : ['Alice', 'Bob', 'Carol', 'Dave', 'Eve', 'Frank', 'Grace', 'Hank', 'Ivy', 'Jack'],
    'Age'          : [28, 35, None, 22, 29, 42, 27, None, 31, 26],
    'Gender'       : ['F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M'],
    'Department'   : ['Tech', 'Finance', 'tech', 'HR', 'Finance', 'Tech', 'hr', 'Tech', 'Finance', 'HR'],
    'Salary'       : [55000, 72000, 48000, None, 58000, 90000, 51000, 67000, None, 44000],
    'YearsExp'     : [3, 8, 2, 1, 5, 15, 2, 9, 6, 1],
    'PerformScore' : [4.2, 3.8, 4.5, 3.1, None, 4.9, 3.7, 4.0, 4.3, None],
    'Left'         : [0, 1, 0, 0, 1, 0, 0, 1, 0, 1]
}

df = pd.DataFrame(data)
df

# %%
# Use .info() to see dtypes and null counts


# Use .describe() to see summary statistics for numeric columns

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# .info() should show:
#   - 10 rows, 8 columns
#   - Age: 8 non-null (2 missing)
#   - Salary: 8 non-null (2 missing)
#   - PerformScore: 8 non-null (2 missing)
#   - All other columns: 10 non-null
#
# .describe() should show:
#   - YearsExp ranges from 1 to 15
#   - Salary ranges from 44000 to 90000
#   - PerformScore ranges from 3.1 to 4.9
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 6 — Audit Missing Data
#
# Before any analysis or reporting, a data analyst must understand the
# completeness of their dataset. An incomplete report can mislead stakeholders.
#
# Using the `df` employee dataset:
# 1. Count the number of nulls in each column.
# 2. Calculate the **percentage** of missing values per column.
# 3. Print a boolean DataFrame showing exactly which cells are null (`df.isnull()`).
# 4. How many total missing values exist across the entire DataFrame?

# %%
# 1. Null count per column


# 2. Percentage of nulls per column (round to 1 decimal place)


# 3. Boolean null map


# 4. Total missing values in the whole DataFrame

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Null counts:
# Age             2
# Salary          2
# PerformScore    2
# (all others)    0
#
# Null percentages:
# Age             20.0%
# Salary          20.0%
# PerformScore    20.0%
#
# Total missing values: 6
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 7 — Fill Missing Values
#
# HR has asked you to prepare a clean version of the employee dataset for a headcount report.
# Missing values must be filled before the report can be generated.
#
# Using `df`:
# 1. Fill missing `Age` values with the **median** age. Assign back to `df['Age']`.
# 2. Fill missing `Salary` values with the **mean** salary. Assign back to `df['Salary']`.
# 3. Fill missing `PerformScore` values with the **median** score. Assign back to `df['PerformScore']`.
# 4. Confirm that `df.isnull().sum().sum()` now returns `0`.

# %%
# 1. Fill Age with median


# 2. Fill Salary with mean


# 3. Fill PerformScore with median


# 4. Confirm zero nulls remain

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Age median fill value  : 28.5
# Salary mean fill value : 60625.0
# PerformScore median    : 4.1
#
# Total nulls remaining  : 0
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 8 — Fix Messy Category Data
#
# A common real-world problem: the same department has been entered in multiple ways
# (`'tech'`, `'Tech'`, `'hr'`, `'HR'`). This breaks grouping and reporting.
#
# Using `df`:
# 1. Run `df['Department'].value_counts()` — notice the inconsistency.
# 2. Fix it by standardising `Department` to Title Case using `.str.strip().str.title()`.
# 3. Run `value_counts()` again to confirm only 3 unique departments remain: `Tech`, `Finance`, `HR`.
# 4. How many employees are in each department?

# %%
# 1. Check current value counts — spot the inconsistency


# 2. Fix the Department column


# 3. Check value counts again — should show only 3 departments


# 4. How many employees per department?

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Before fix:
# Tech       3
# Finance    3
# HR         2
# tech       1
# hr         1
#
# After fix:
# Finance    3
# Tech       3
# HR         2
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 9 — Sort and Rank Employees
#
# The HR manager wants two sorted views of the employee data to prepare for a performance review.
#
# Using `df`:
# 1. Sort by `Salary` from highest to lowest and print the result.
# 2. Sort by `Department` (A to Z), then by `Salary` within each department (highest first).
# 3. Rename the column `YearsExp` to `Experience` and `PerformScore` to `PerformanceScore`.
#    Use `.rename(columns={...})`.
# 4. Print `df.columns` to confirm the rename worked.

# %%
# 1. Sort by Salary descending


# 2. Sort by Department A-Z, then Salary descending within each


# 3. Rename YearsExp and PerformScore


# 4. Confirm column names

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Top salary: Frank (90000), Bob (72000), Hank (67000), ...
#
# Sorted by Dept + Salary: Finance: Bob 72000, Eve 58000, Ivy ~60625...
#
# Updated columns:
# Index(['Name','Age','Gender','Department','Salary','Experience','PerformanceScore','Left'])
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 10 — Create New Columns (Feature Engineering)
#
# Derived columns are a core part of data analysis — you create new information
# from columns that already exist.
#
# Using `df` (with `YearsExp` renamed to `Experience` from Exercise 9):
# 1. Add a column `SalaryPerYear` = `Salary / Experience`. This shows earnings efficiency.
# 2. Add a column `SeniorityLevel` using `.apply()` with the following rules:
#    - `'Junior'`  if Experience <= 2
#    - `'Mid'`     if Experience is 3 to 7
#    - `'Senior'`  if Experience >= 8
# 3. Add a column `HighEarner` = `True` if `Salary` is above the **median** salary.
#    (One line — no apply needed.)
# 4. Print `df[['Name', 'Experience', 'Salary', 'SeniorityLevel', 'HighEarner']].head(10)`.

# %%
# 1. SalaryPerYear


# 2. SeniorityLevel using apply()
def assign_seniority(exp):
    # fill in the logic
    pass


# 3. HighEarner — one line


# 4. Preview the result

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
#     Name  Experience   Salary SeniorityLevel  HighEarner
# 0  Alice           3    55000            Mid       False
# 1    Bob           8    72000         Senior        True
# 2  Carol           2    48000         Junior       False
# 3   Dave           1    60625            Junior     False
# 4    Eve           5    58000            Mid       False
# 5  Frank          15    90000         Senior        True
# 6  Grace           2    51000         Junior       False
# 7   Hank           9    67000         Senior        True
# 8    Ivy           6    60625            Mid       False
# 9   Jack           1    44000         Junior       False
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 11 — Department-Level Summary (groupby)
#
# Your manager wants a department summary report to present at the next leadership meeting.
# Use `groupby` to build it.
#
# Using `df`:
# 1. Group by `Department` and calculate the **mean** `Salary`. Which department pays the most?
# 2. Group by `Department` and use `.agg()` to calculate all of the following at once:
#    - Mean `Salary`
#    - Median `Experience`
#    - Count of employees (use `'Name'` with `'count'`)
#    - Mean `PerformanceScore`
# 3. Group by `Department` and `Gender` — calculate average `Salary` for each combination.

# %%
# 1. Mean salary by department


# 2. Multi-stat aggregation using .agg()


# 3. Multi-level groupby: Department + Gender

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Mean salary by department:
#   Finance    ~63541
#   HR         ~52312
#   Tech       ~70656  <- highest
#
# Multi-stat table shows per department:
#   employee count, avg salary, median experience, avg performance score
#
# Dept + Gender salary: shows M vs F breakdown within each department
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 12 — Employee Attrition Analysis (groupby + value_counts)
#
# The HR team wants to understand which types of employees are leaving the company.
# The `Left` column records this: `1` = left, `0` = stayed.
#
# Using `df`:
# 1. Use `value_counts(normalize=True)` on `Left` — what percentage of employees left?
# 2. Group by `Left` and calculate the mean of all numeric columns.
#    Look at the result — do leavers (`1`) tend to have fewer years of experience than stayers (`0`)?
# 3. Group by `Department` and calculate the **sum** of `Left`.
#    Which department lost the most employees?

# %%
# 1. Attrition rate


# 2. Average profile of leavers vs stayers


# 3. Attrition count by department

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Attrition rate:
# 0    0.6  (60% stayed)
# 1    0.4  (40% left)
#
# Leavers (Left=1) tend to have lower Experience and lower Salary on average
#
# Attrition by department:
#   Finance    2
#   HR         1
#   Tech       1
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 13 — Salary Outlier Detection (IQR method)
#
# An analyst preparing a compensation benchmarking report needs to flag any
# salaries that are unusually high or low compared to the rest of the workforce.
# The standard method used in statistics is the **IQR (Interquartile Range)** rule.
#
# Using `df`:
# 1. Calculate Q1 (25th percentile) and Q3 (75th percentile) of `Salary`.
# 2. Calculate IQR = Q3 - Q1.
# 3. Define the lower bound as Q1 - 1.5 * IQR and upper bound as Q3 + 1.5 * IQR.
# 4. Filter and print any rows where `Salary` falls outside these bounds.
# 5. Print a message saying how many outliers were found.

# %%
# 1. Q1 and Q3


# 2. IQR


# 3. Bounds


# 4. Filter outlier rows


# 5. Print how many outliers found

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# Q1     : ~49250
# Q3     : ~67000
# IQR    : ~17750
# Lower  : ~22625
# Upper  : ~93625
#
# Outliers found: 0
# (Frank at 90000 is within the upper bound of ~93625 for this small dataset)
# ```
#
# </details>

# %% [markdown]
# ---
# ## Exercise 15 — End-to-End: Save a Clean Report
#
# You have now explored, cleaned, and enriched the employee dataset.
# As a final step, a data analyst always validates their work and saves the output.
#
# Using `df`:
# 1. Run a final data quality check:
#    - `df.isnull().sum()` — should all be zero
#    - `df.dtypes` — review what types remain
#    - `df.shape` — confirm the row and column count
# 2. Select only the columns useful for a management report:
#    `['Name', 'Department', 'Salary', 'Experience', 'SeniorityLevel', 'PerformanceScore', 'HighEarner']`
#    and store it in a variable called `report`.
# 3. Sort `report` by `Department`, then by `Salary` descending.
# 4. Save `report` to a CSV file called `employee_report.csv` using `index=False`.
# 5. Read it back and print the first 5 rows to confirm it saved correctly.

# %%
# 1. Final data quality checks


# 2. Select report columns


# 3. Sort the report


# 4. Save to CSV


# 5. Read back and print first 5 rows

# %% [markdown]
# <details>
# <summary><strong>Expected Output</strong></summary>
#
# ```
# isnull check  : all zeros
# shape         : (10, 11+)  — depends on columns added in earlier exercises
#
# Report sorted by Department + Salary (first 5 rows):
#
#     Name Department   Salary  Experience SeniorityLevel  PerformanceScore  HighEarner
# 1    Bob    Finance  72000.0           8         Senior               3.8        True
# 4    Eve    Finance  58000.0           5            Mid               4.1       False
# 8    Ivy    Finance  60625.0           6            Mid               4.3       False
# 0  Alice       HR   55000.0           3            Mid               4.2       False
# ...
#
# File saved: employee_report.csv
# ```
#
# </details>
